# %%
from azureml.core import Workspace, Environment

ws = Workspace.from_config()

# %%
from azureml.core import ScriptRunConfig, Experiment
from azureml.core.environment import Environment

exp = Experiment(name="my-exp", workspace = ws)

# Instantiate environment
# myenv = Environment(name="my-env")
myenv = Environment.from_conda_specification("my-env", "my-env.yml")

# Add training script to run config
runconfig = ScriptRunConfig(source_directory=".", script="train.py")

# Attach compute target to run config
runconfig.run_config.target = "local"

# Attach environment to run config
runconfig.run_config.environment = myenv

# Submit run 
run = exp.submit(runconfig)

# Show each step of run 
run.wait_for_completion(show_output=True)
# Out:
# RunId: my-exp_1599062098_259e0255
# Web View: https://ml.azure.com/experiments/my-exp/runs/my-exp_1599062098_259e0255?wsid=/subscriptions/f56912be-98e5-44e3-9e64-54bc52cef4a7/resourcegroups/RG-Auto-ML/workspaces/wk-qa
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# [2020-09-02T15:54:59.635114] Using urllib.request Python 3.0 or later
# Streaming log file azureml-logs/60_control_log.txt
# Starting the daemon thread to refresh tokens in background for process with pid = 2674
# Running: ['/bin/bash', '/tmp/azureml_runs/my-exp_1599062098_259e0255/azureml-environment-setup/conda_env_checker.sh']
# Materialized conda environment not found on target: /home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8
#
#
# Logging experiment preparation status in history service.
# Running: ['/bin/bash', '/tmp/azureml_runs/my-exp_1599062098_259e0255/azureml-environment-setup/conda_env_builder.sh']
# Running: ['conda', '--version']
# conda 4.5.12
#
# Creating conda environment...
# Running: ['conda', 'env', 'create', '-p', '/home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8', '-f', 'azureml-environment-setup/mutated_conda_dependencies.yml']
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.12
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults
#   Using cached azureml_defaults-1.13.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-sdk==1.12.0
#   Using cached azureml_sdk-1.12.0-py3-none-any.whl (4.4 kB)
# Collecting pandas
#   Using cached pandas-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (10.5 MB)
# Collecting catboost
#   Using cached catboost-0.24.1-cp36-none-manylinux1_x86_64.whl (66.1 MB)
# Collecting azure.cosmos==4.0.0
#   Downloading azure_cosmos-4.0.0-py2.py3-none-any.whl (134 kB)
# Collecting azureml-core~=1.13.0
#   Using cached azureml_core-1.13.0-py3-none-any.whl (2.0 MB)
# Collecting werkzeug==0.16.1
#   Using cached Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Processing /home/azureuser/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee/json_logging_py-0.2-py3-none-any.whl
# Collecting azureml-dataset-runtime[fuse]~=1.13.0
#   Using cached azureml_dataset_runtime-1.13.0-py3-none-any.whl (3.2 kB)
# Collecting gunicorn==19.9.0
#   Using cached gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Using cached configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Using cached Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Using cached applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Using cached azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-train-automl-client~=1.12.0
#   Using cached azureml_train_automl_client-1.12.0.post1-py3-none-any.whl (97 kB)
# Collecting azureml-pipeline~=1.12.0
#   Using cached azureml_pipeline-1.12.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train~=1.12.0
#   Using cached azureml_train-1.12.0-py3-none-any.whl (3.2 kB)
# Collecting pytz>=2017.2
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8/lib/python3.6/site-packages (from pandas->-r /tmp/azureml_runs/my-exp_1599062098_259e0255/azureml-environment-setup/condaenv.60bpvov1.requirements.txt (line 3)) (1.19.1)
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Requirement already satisfied: six in /home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8/lib/python3.6/site-packages (from catboost->-r /tmp/azureml_runs/my-exp_1599062098_259e0255/azureml-environment-setup/condaenv.60bpvov1.requirements.txt (line 4)) (1.15.0)
# Collecting plotly
#   Using cached plotly-4.9.0-py2.py3-none-any.whl (12.9 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.3.1-cp36-cp36m-manylinux1_x86_64.whl (11.6 MB)
# Requirement already satisfied: scipy in /home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8/lib/python3.6/site-packages (from catboost->-r /tmp/azureml_runs/my-exp_1599062098_259e0255/azureml-environment-setup/condaenv.60bpvov1.requirements.txt (line 4)) (1.5.2)
# Collecting graphviz
#   Using cached graphviz-0.14.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Using cached azure_core-1.8.0-py2.py3-none-any.whl (121 kB)
# Collecting msrestazure>=0.4.33
#   Using cached msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-common>=1.1.12
#   Using cached azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting contextlib2
#   Using cached contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Using cached azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting docker
#   Using cached docker-4.3.1-py2.py3-none-any.whl (145 kB)
# Collecting pyopenssl
#   Using cached pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting PyJWT
#   Using cached PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Using cached azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Using cached azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Using cached azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968 kB)
# Collecting urllib3>=1.23
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting azure-graphrbac>=0.40.0
#   Using cached azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Using cached azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting requests>=2.19.1
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting SecretStorage
#   Using cached SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting jsonpickle
#   Using cached jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting jmespath
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Using cached cryptography-3.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting pathspec
#   Using cached pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting adal>=1.2.0
#   Using cached adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting backports.tempfile
#   Using cached backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrest>=0.5.1
#   Using cached msrest-0.6.18-py2.py3-none-any.whl (84 kB)
# Collecting ndg-httpsclient
#   Using cached ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting ruamel.yaml>=0.15.35
#   Using cached ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting azureml-dataprep<2.1.0a,>=2.0.1a
#   Using cached azureml_dataprep-2.0.7-py3-none-any.whl (28.2 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Using cached pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Processing /home/azureuser/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079/fusepy-3.0.1-py3-none-any.whl
# Collecting itsdangerous>=0.24
#   Using cached itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Using cached Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Processing /home/azureuser/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b/liac_arff-2.5.0-py3-none-any.whl
# Processing /home/azureuser/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352/dill-0.3.2-py3-none-any.whl
# Collecting azureml-telemetry~=1.12.0
#   Using cached azureml_telemetry-1.12.0-py3-none-any.whl (29 kB)
# Collecting azureml-automl-core~=1.12.0
#   Using cached azureml_automl_core-1.12.0-py3-none-any.whl (158 kB)
# Collecting azureml-pipeline-steps~=1.12.0
#   Using cached azureml_pipeline_steps-1.12.0-py3-none-any.whl (59 kB)
# Collecting azureml-pipeline-core~=1.12.0
#   Using cached azureml_pipeline_core-1.12.0-py3-none-any.whl (300 kB)
# Collecting azureml-train-core~=1.12.0
#   Using cached azureml_train_core-1.12.0-py3-none-any.whl (8.6 MB)
# Processing /home/azureuser/.cache/pip/wheels/ac/cb/8a/b27bf6323e2f4c462dcbf77d70b7c5e7868a7fbe12871770cf/retrying-1.3.3-py3-none-any.whl
# Requirement already satisfied: certifi>=2020.06.20 in /home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8/lib/python3.6/site-packages (from matplotlib->catboost->-r /tmp/azureml_runs/my-exp_1599062098_259e0255/azureml-environment-setup/condaenv.60bpvov1.requirements.txt (line 4)) (2020.6.20)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.2.0-cp36-cp36m-manylinux1_x86_64.whl (88 kB)
# Collecting websocket-client>=0.32.0
#   Using cached websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting jeepney>=0.4.2
#   Using cached jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting importlib-metadata
#   Using cached importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Using cached cffi-1.14.2-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting backports.weakref
#   Using cached backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Using cached ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting azureml-dataprep-native<21.0.0,>=20.0.2
#   Using cached azureml_dataprep_native-20.0.2-cp36-cp36m-manylinux1_x86_64.whl (10.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Using cached cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Using cached azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Using cached dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting MarkupSafe>=0.23
#   Using cached MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.12.0
#   Using cached azureml_train_restclients_hyperdrive-1.12.0-py3-none-any.whl (18 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting pycparser
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting msal-extensions~=0.1.3
#   Using cached msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Using cached msal-1.4.3-py2.py3-none-any.whl (49 kB)
# Collecting distro>=1.2.0
#   Using cached distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting portalocker~=1.0
#   Using cached portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Installing collected packages: PyJWT, pycparser, cffi, cryptography, python-dateutil, idna, chardet, urllib3, requests, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, contextlib2, azure-mgmt-storage, websocket-client, docker, pyopenssl, azure-mgmt-authorization, azure-mgmt-containerregistry, azure-mgmt-resource, azure-graphrbac, azure-mgmt-keyvault, jeepney, SecretStorage, zipp, importlib-metadata, jsonpickle, jmespath, pytz, pathspec, backports.weakref, backports.tempfile, pyasn1, ndg-httpsclient, ruamel.yaml.clib, ruamel.yaml, azureml-core, werkzeug, json-logging-py, azureml-dataprep-native, cloudpickle, azure-core, portalocker, msal, msal-extensions, azure-identity, distro, dotnetcore2, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, gunicorn, configparser, itsdangerous, click, MarkupSafe, Jinja2, flask, applicationinsights, liac-arff, dill, pandas, azureml-model-management-sdk, azureml-defaults, azureml-telemetry, azureml-automl-core, azureml-train-automl-client, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-train, azureml-sdk, retrying, plotly, pyparsing, pillow, cycler, kiwisolver, matplotlib, graphviz, catboost, azure.cosmos
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-11.2.0 azure.cosmos azureml-automl-core-1.12.0 azureml-core-1.13.0 azureml-dataprep-2.0.7 azureml-dataprep-native-20.0.2 azureml-dataset-runtime-1.13.0 azureml-defaults-1.13.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-pipeline-1.12.0 azureml-pipeline-core-1.12.0 azureml-pipeline-steps-1.12.0 azureml-sdk-1.12.0 azureml-telemetry-1.12.0 azureml-train-1.12.0 azureml-train-automl-client-1.12.0.post1 azureml-train-core-1.12.0 azureml-train-restclients-hyperdrive-1.12.0 backports.tempfile-1.0 backports.weakref-1.0.post1 catboost-0.24.1 cffi-1.14.2 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.1 cycler-0.10.0 dill-0.3.2 distro-1.5.0 docker-4.3.1 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 graphviz-0.14.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 kiwisolver-1.2.0 liac-arff-2.5.0 matplotlib-3.3.1 msal-1.4.3 msal-extensions-0.1.3 msrest-0.6.18 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.1.1 pathspec-0.8.0 pillow-7.2.0 plotly-4.9.0 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 pyparsing-2.4.7 python-dateutil-2.8.1 pytz-2020.1 requests-2.24.0 requests-oauthlib-1.3.0 retrying-1.3.3 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.10 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
# azureml-telemetry 1.12.0 requires azureml-core~=1.12.0, but you'll have azureml-core 1.13.0 which is incompatible.
# azureml-automl-core 1.12.0 requires azureml-dataset-runtime~=1.12.0, but you'll have azureml-dataset-runtime 1.13.0 which is incompatible.
# azureml-train-automl-client 1.12.0.post1 requires azureml-core~=1.12.0, but you'll have azureml-core 1.13.0 which is incompatible.
# azureml-train-automl-client 1.12.0.post1 requires azureml-dataset-runtime~=1.12.0, but you'll have azureml-dataset-runtime 1.13.0 which is incompatible.
# azureml-train-core 1.12.0 requires azureml-core~=1.12.0, but you'll have azureml-core 1.13.0 which is incompatible.
# azureml-pipeline-core 1.12.0 requires azureml-core~=1.12.0, but you'll have azureml-core 1.13.0 which is incompatible.
# azureml-sdk 1.12.0 requires azureml-core~=1.12.0, but you'll have azureml-core 1.13.0 which is incompatible.
# azureml-sdk 1.12.0 requires azureml-dataset-runtime[fuse]~=1.12.0, but you'll have azureml-dataset-runtime 1.13.0 which is incompatible.
# #
# # To activate this environment, use:
# # > source activate /home/azureuser/.azureml/envs/azureml_256d90f515379e75f87022d46e7cacf8
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# [2020-09-02T15:55:47.648343] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['train.py'])
# Starting the daemon thread to refresh tokens in background for process with pid = 2853
# Entering Run History Context Manager.
# Current directory:  /tmp/azureml_runs/my-exp_1599062098_259e0255
# Preparing to call script [ train.py ] with arguments: []
# After variable expansion, calling script [ train.py ] with arguments: []
#
# Script type = None
# azure cosmos VERSION 4.0.0
# Starting the daemon thread to refresh tokens in background for process with pid = 2853
#
#
# The experiment completed successfully. Finalizing run...
# Logging experiment finalizing status in history service.
# [2020-09-02T15:55:49.133520] TimeoutHandler __init__
# [2020-09-02T15:55:49.133554] TimeoutHandler __enter__
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.06846046447753906 seconds
# [2020-09-02T15:55:49.558827] TimeoutHandler __exit__
#
# Execution Summary
# =================
# RunId: my-exp_1599062098_259e0255
# Web View: https://ml.azure.com/experiments/my-exp/runs/my-exp_1599062098_259e0255?wsid=/subscriptions/f56912be-98e5-44e3-9e64-54bc52cef4a7/resourcegroups/RG-Auto-ML/workspaces/wk-qa
# {'runId': 'my-exp_1599062098_259e0255',
#  'target': 'local',
#  'status': 'Completed',
#  'startTimeUtc': '2020-09-02T15:55:47.457093Z',
#  'endTimeUtc': '2020-09-02T15:55:50.390543Z',
#  'properties': {'_azureml.ComputeTargetType': 'local',
#   'ContentSnapshotId': 'b88678da-12f5-4965-8633-80ac6a92c34c'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'scriptType': None,
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'local',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'environment': {'name': 'my-env',
#    'version': 'Autosave_2020-09-02T15:54:58Z_2c362964',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'dependencies': ['python=3.6.9',
#       'numpy',
#       'scikit-learn',
#       {'pip': ['azureml-defaults',
#         'azureml-sdk==1.12.0',
#         'pandas',
#         'catboost',
#         'azure.cosmos==4.0.0']}],
#      'name': 'azureml_256d90f515379e75f87022d46e7cacf8'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'cmAksCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/60_control_log.txt': 'https://wkqa0820136335.blob.core.windows.net/azureml/ExperimentRun/dcid.my-exp_1599062098_259e0255/azureml-logs/60_control_log.txt?sv=2019-02-02&sr=b&sig=OYfleA9P1%2BHO4zkho87%2FOk09XrAE37BoI%2B6lm7kFC3I%3D&st=2020-09-02T15%3A45%3A53Z&se=2020-09-02T23%3A55%3A53Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://wkqa0820136335.blob.core.windows.net/azureml/ExperimentRun/dcid.my-exp_1599062098_259e0255/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=ZF14fKb7r%2FzU4h%2FKI3DLsDj6VLwJ6fhmdWUNE6ncchE%3D&st=2020-09-02T15%3A45%3A53Z&se=2020-09-02T23%3A55%3A53Z&sp=r',
#   'logs/azureml/2853_azureml.log': 'https://wkqa0820136335.blob.core.windows.net/azureml/ExperimentRun/dcid.my-exp_1599062098_259e0255/logs/azureml/2853_azureml.log?sv=2019-02-02&sr=b&sig=1roLm8y3Hyzv7rulMq9NqzOhY5BoqEWqa0aj3HsjWaE%3D&st=2020-09-02T15%3A45%3A53Z&se=2020-09-02T23%3A55%3A53Z&sp=r'}}
